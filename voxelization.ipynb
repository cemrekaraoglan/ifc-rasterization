# %% [markdown]
# # IFC Rasterization for Efficient Spatial Analysis

# %% [markdown]
# ## Intro

# %% [markdown]
# ### Import libraries and the IFC model:

# %%
import pyvista as pv
import numpy as np
from typing import Any, Tuple
import ifcopenshell
import logging
from importlib import reload 
import multiprocessing
import ifcopenshell
import ifcopenshell.geom
import time
import vtk
ifc_file = ifcopenshell.open(r"IFC Files\Project1.ifc")
#ifc_file = ifcopenshell.open(r"IFC Files\Duplex.ifc")

# %% [markdown]
# ### Logging setup:

# %%
#set up logging
reload(logging)
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.INFO, filename="test.log",  datefmt='%I:%M:%S')

# Configure logging to write to a file
# logging.basicConfig(filename='./app.log',  level=logging.INFO)
logname="./vista.log"
logging.basicConfig(filename=logname,
                    filemode='a',
                    format='%(asctime)s,%(msecs)d %(name)s %(levelname)s %(message)s',
                    datefmt='%H:%M:%S',
                    level=logging.INFO)

logging.info("Running IFC Voxelizer")

logger = logging.getLogger('IFCVoxelizer')
logger.debug("hello")

# %% [markdown]
# ## Functions

# %%
def to_vtk_faces(faces : Tuple[tuple]) -> np.ndarray:
    faces=np.array(faces, dtype=np.int16)
    num_insertions = (len(faces) - 1) // 3
    # Generate an array of indices for insertions
    indices = np.arange(3, 3 * (num_insertions + 1), 3)
    indices = np.insert(indices, 0, 0)
    faces = np.insert(faces, indices, 3)
    return faces

def vtk_block_by_building_element(ifc_file):
    building_elements = ifc_file.by_type("IfcBuildingElement")
    settings = ifcopenshell.geom.settings()
    settings.set(settings.USE_WORLD_COORDS, True)
    settings.set(settings.APPLY_DEFAULT_MATERIALS, True)
    iterator = ifcopenshell.geom.iterator(settings, ifc_file, multiprocessing.cpu_count())
    multiblock = pv.MultiBlock()
    element_information = {} # Dictionary to hold element information
    exclude_list = ["IfcSpace", "IfcOpeningElement"]

    if iterator.initialize():
        while True:
            shape = iterator.get()
            if shape.type not in exclude_list:
                element = ifc_file.by_guid(shape.guid)
                           
                faces = shape.geometry.faces
                verts = shape.geometry.verts
                poly_data = pv.PolyData(list(verts), to_vtk_faces(faces))
                multiblock.append(poly_data)
                  
                if element in building_elements:
                #print(element.all_attributes()) --> why doesn't it work?
                        
                    element_information[shape.guid] = {
                    "Geo": poly_data, 
                    "Type": shape.type,
                    "Name": element.Name,
                    "Description": element.Description
                    }
                            
                       
            if not iterator.next():
                break
                
    return multiblock, element_information

def create_uniform_grid(bounds, voxel_size):
    """Create a uniform grid within the given bounds."""
    x = np.arange(bounds[0], bounds[1] + voxel_size, voxel_size)
    y = np.arange(bounds[2], bounds[3] + voxel_size, voxel_size)
    z = np.arange(bounds[4], bounds[5] + voxel_size, voxel_size)
    return pv.StructuredGrid(*np.meshgrid(x, y, z))

def boxes_touch(A, B):
    """
    Check if two 3D bounding boxes touch or overlap.
    
    Parameters:
    - A, B: Tuples representing the bounds of boxes A and B.
      Each tuple should be in the format (xmin, xmax, ymin, ymax, zmin, zmax).
    
    Returns:
    - True if the boxes touch or overlap, otherwise False.
    """
    
    # Check for overlap in the x, y, and z dimensions
    overlap_x = A[0] <= B[1] and A[1] >= B[0]
    overlap_y = A[2] <= B[3] and A[3] >= B[2]
    overlap_z = A[4] <= B[5] and A[5] >= B[4]
    
    # Return True if all dimensions overlap, otherwise False
    return overlap_x and overlap_y and overlap_z

# %%
def voxelize_space(meshes, voxel_size, mesh_info):
    """Voxelize space and check intersections with given mesh."""
    grid = create_uniform_grid(meshes.bounds, voxel_size)

    num_points = grid.cell_centers().n_points

    #mask = np.zeros(num_points, dtype=bool)
    mask2 = np.zeros(num_points, dtype=bool)

    cell_to_guid = {}

    print(f'Total number of voxels: {num_points}')

    select_enclosed = vtk.vtkSelectEnclosedPoints()
    #select_enclosed.SetInputData(grid.cell_centers())
       
    for guid, mesh_data in mesh_info.items():

        mesh = mesh_data['Geo']
        #select_enclosed.SetSurfaceData(mesh)
        #select_enclosed.Update()
        mesh_bounds = mesh.bounds
        

        for i in range(num_points):
            
            cell = grid.extract_cells(i)
            cell_bounds = cell.bounds         

            if boxes_touch(mesh_bounds, cell_bounds):
                if not mask2[i]:
                    mask2[i] = True          
             
            '''if not mask[i] and select_enclosed.IsInside(i):
                mask[i] = True
                cell_to_guid[i] = guid'''
            
            
                
    return grid, mask2, cell_to_guid

# %% [markdown]
# ## Voxelization

# %%
all_meshes, info = vtk_block_by_building_element(ifc_file)

p = pv.Plotter()

start_time = time.time()

voxel_size = 0.2


# Voxelize the entire space of the combined mesh
grid, mask2, cell_info = voxelize_space(all_meshes, voxel_size, info)

# Prepare to store cell-IFC-object mappings
cell_data = {}

for cell_id, guid in cell_info.items():
    cell_data[cell_id] = info[guid]

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to voxelize: {elapsed_time:.4f} seconds")

# Visualization
p.add_mesh(grid, opacity=0.3, show_edges=True)
#p.add_mesh(grid.extract_cells(np.where(mask)[0]), color="red", opacity=0.7)
 
p.add_mesh(grid.extract_cells(np.where(mask2)[0]), color="blue", opacity=0.5)
p.show()
'''
num_points = grid.cell_centers().n_points

# Calculate difference
diff_mask = mask != mask2

# Get indices where masks differ
indices = np.where(diff_mask)[0]

mask_dif = np.zeros(num_points, dtype=bool)
for n in range(num_points):
    if n in indices:
        mask_dif[n] = True'''
# Out:
# Total number of voxels: 10944
# Time taken to voxelize: 45.2474 seconds
# Widget(value="<iframe src='http://localhost:52386/index.html?ui=P_0x1cc31ec5c30_0&reconnect=auto' style='width…
# '\nnum_points = grid.cell_centers().n_points\n\n# Calculate difference\ndiff_mask = mask != mask2\n\n# Get indices where masks differ\nindices = np.where(diff_mask)[0]\n\nmask_dif = np.zeros(num_points, dtype=bool)\nfor n in range(num_points):\n    if n in indices:\n        mask_dif[n] = True'

# %%
def detailed_voxelization(cell_bounds, voxel_size, mesh_info):
    grid = create_uniform_grid(cell_bounds, voxel_size)
    num_points = grid.cell_centers().n_points
    mask = np.zeros(num_points, dtype=bool)
    mask2 = np.zeros(num_points, dtype=bool)
    select_enclosed = vtk.vtkSelectEnclosedPoints()
    select_enclosed.SetInputData(grid.cell_centers())

    for guid, mesh_data in mesh_info.items():
        mesh = mesh_data['Geo']
        mesh_bounds = mesh.bounds
        select_enclosed.SetSurfaceData(mesh)
        select_enclosed.Update()
    
        for i in range(num_points):
            cell = grid.extract_cells(i)
            cell_bounds = cell.bounds                   
                
            if not mask[i] and select_enclosed.IsInside(i):
                mask[i] = True

            if boxes_touch(mesh_bounds, cell_bounds):
                if not mask2[i]:
                    mask2[i] = True
                
    return grid, mask, mask2

for n in range(num_points):
    if mask_dif[n] == True:
        cell = grid.extract_cells(n)
        cell_bounds = cell.bounds                   
        
        det_grid, det_mask1, det_mask2 = detailed_voxelization(cell_bounds, voxel_size/2, info)

        p.add_mesh(det_grid.extract_cells(np.where(det_mask2)[0]), color="red", opacity=0.7)

p.add_mesh(grid.extract_cells(np.where(mask_dif)[0]), color = "green", opacity=0.2)
p.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 35
#      31         cell_bounds = cell.bounds
#      33         det_grid, det_mask1, det_mask2 = detailed_voxelization(cell_bounds, voxel_size/2, info)
# ---> 35         p.add_mesh(det_grid.extract_cells(np.where(det_mask2)[0]), color="red", opacity=0.7)
#      37 p.add_mesh(grid.extract_cells(np.where(mask_dif)[0]), color = "green", opacity=0.2)
#      38 p.show()
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\pyvista\plotting\plotter.py:3581, in BasePlotter.add_mesh(self, mesh, color, style, scalars, clim, show_edges, edge_color, point_size, line_width, opacity, flip_scalars, lighting, n_colors, interpolate_before_map, cmap, label, reset_camera, scalar_bar_args, show_scalar_bar, multi_colors, name, texture, render_points_as_spheres, render_lines_as_tubes, smooth_shading, split_sharp_edges, ambient, diffuse, specular, specular_power, nan_color, nan_opacity, culling, rgb, categories, silhouette, use_transparency, below_color, above_color, annotations, pickable, preference, log_scale, pbr, metallic, roughness, render, component, emissive, copy_mesh, backface_params, show_vertices, **kwargs)
#    3567 if show_vertices and style not in ['points', 'points_gaussian']:
#    3568     self.add_mesh(
#    3569         extract_surface_algorithm(algo or mesh),
#    3570         style=vertex_style,
#    (...)
#    3578         show_vertices=False,
#    3579     )
# -> 3581 self.add_actor(
#    3582     actor,
#    3583     reset_camera=reset_camera,
#    3584     name=name,
#    3585     pickable=pickable,
#    3586     render=render,
#    3587     remove_existing_actor=remove_existing_actor,
#    3588 )
#    3590 # hide scalar bar if using special scalars
#    3591 if scalar_bar_args.get('title') == '__custom_rgba':
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\pyvista\plotting\plotter.py:1279, in BasePlotter.add_actor(self, *args, **kwargs)
#    1276 @wraps(Renderer.add_actor)
#    1277 def add_actor(self, *args, **kwargs):
#    1278     """Wrap ``Renderer.add_actor``."""
# -> 1279     return self.renderer.add_actor(*args, **kwargs)
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\pyvista\plotting\renderer.py:810, in Renderer.add_actor(self, actor, reset_camera, name, culling, pickable, render, remove_existing_actor)
#     808     self.reset_camera(render)
#     809 elif render:
# --> 810     self.parent.render()
#     812 self.update_bounds_axes()
#     814 if isinstance(culling, str):
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\pyvista\plotting\plotter.py:1845, in BasePlotter.render(self)
#    1843     self._rendered = True
#    1844 for callback in self._on_render_callbacks:
# -> 1845     callback(self)
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\pyvista\trame\views.py:23, in _BasePyVistaView.__init__.<locals>.<lambda>(*args)
#      21 self._plotter = weakref.ref(plotter)
#      22 self.pyvista_initialize()
# ---> 23 self._plotter_render_callback = lambda *args: self.update()
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\widgets\vtk\common.py:551, in VtkRemoteLocalView.update(self, reset_camera, widgets, orientation_axis, **kwargs)
#     549 if self.__rendering:
#     550     self.update_image(reset_camera)
# --> 551 self.update_geometry(
#     552     reset_camera=reset_camera,
#     553     widgets=widgets,
#     554     orientation_axis=orientation_axis,
#     555 )
#     557 if reset_camera:
#     558     self.server.js_call(
#     559         self.__ref,
#     560         "setCamera",
#     561         MODULE.camera(self.__view),
#     562     )
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\widgets\vtk\common.py:499, in VtkRemoteLocalView.update_geometry(self, reset_camera, widgets, orientation_axis, **kwargs)
#     491     delta_state = MODULE.scene(
#     492         self.__view,
#     493         new_state=False,
#     494         widgets=widgets,
#     495         orientation_axis=orientation_axis,
#     496     )
#     497     self.server.protocol.publish("trame.vtk.delta", delta_state)
# --> 499 full_state = MODULE.scene(
#     500     self.__view,
#     501     new_state=True,
#     502     widgets=widgets,
#     503     orientation_axis=orientation_axis,
#     504 )
#     505 self.server.state[self.__scene_id] = full_state
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\modules\vtk\__init__.py:225, in scene(render_window, reset_camera, new_state, widgets, orientation_axis)
#     222 def scene(
#     223     render_window, reset_camera=False, new_state=True, widgets=None, orientation_axis=0
#     224 ):
# --> 225     scene_state = HELPER.scene(
#     226         render_window, new_state, widgets=widgets, orientation_axis=orientation_axis
#     227     )
#     228     if reset_camera:
#     229         scene_state.setdefault("extra", {})["resetCamera"] = 1
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\modules\vtk\__init__.py:69, in Helper.scene(self, render_window, new_state, widgets, orientation_axis, **kwargs)
#      66 def scene(
#      67     self, render_window, new_state=False, widgets=None, orientation_axis=0, **kwargs
#      68 ):
# ---> 69     return self._trame_server.protocol_call(
#      70         "viewport.geometry.view.get.state",
#      71         self.id(render_window),
#      72         new_state,
#      73         widgets=widgets,
#      74         orientation_axis=orientation_axis,
#      75     )
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_server\core.py:430, in Server.protocol_call(self, method, *args, **kwargs)
#     428 if pair:
#     429     obj, func = pair
# --> 430     return func(obj, *args, **kwargs)
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py:111, in vtkWebLocalRendering.get_view_state(self, view_id, new_subscription, widgets, orientation_axis, **kwargs)
#     109 camera = renderer.GetActiveCamera()
#     110 render_window_id = self.app.GetObjectIdMap().GetGlobalId(s_view)
# --> 111 view_instance = serialize(
#     112     None, render_window, render_window_id, self.context, 1
#     113 )
#     114 view_instance["extra"] = {
#     115     "vtkRefId": reference_id(render_window),
#     116     "centerOfRotation": camera.GetFocalPoint(),
#     117     "camera": reference_id(camera),
#     118 }
#     120 # Handle widgets/behaviors
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\modules\vtk\serializers\serialize.py:19, in serialize(parent, instance, instance_id, context, depth)
#      16 serializer = SERIALIZERS[instance_type] if instance_type in SERIALIZERS else None
#      18 if serializer:
# ---> 19     return serializer(parent, instance, instance_id, context, depth)
#      21 if instance_type not in NO_SERIALIZER_FOR_INSTANCE:
#      22     # Only print the warning once for each type of serializer
#      23     logger.warning(f"!!!No serializer for {instance_type} with id {instance_id}")
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\modules\vtk\serializers\render_windows.py:115, in render_window_serializer(parent, instance, obj_id, context, depth)
#     113 renderer = renderer_collection.GetItemAsObject(r_idx)
#     114 renderer_id = reference_id(renderer)
# --> 115 renderer_instance = serialize(
#     116     instance, renderer, renderer_id, context, depth + 1
#     117 )
#     118 if renderer_instance:
#     119     dependencies.append(renderer_instance)
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\modules\vtk\serializers\serialize.py:19, in serialize(parent, instance, instance_id, context, depth)
#      16 serializer = SERIALIZERS[instance_type] if instance_type in SERIALIZERS else None
#      18 if serializer:
# ---> 19     return serializer(parent, instance, instance_id, context, depth)
#      21 if instance_type not in NO_SERIALIZER_FOR_INSTANCE:
#      22     # Only print the warning once for each type of serializer
#      23     logger.warning(f"!!!No serializer for {instance_type} with id {instance_id}")
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\modules\vtk\serializers\render_windows.py:26, in renderer_serializer(parent, instance, obj_id, context, depth)
#      23 view_prop = view_prop_collection.GetItemAsObject(rp_idx)
#      24 view_prop_id = reference_id(view_prop)
# ---> 26 view_prop_instance = serialize(
#      27     instance, view_prop, view_prop_id, context, depth + 1
#      28 )
#      29 if view_prop_instance:
#      30     dependencies.append(view_prop_instance)
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\modules\vtk\serializers\serialize.py:19, in serialize(parent, instance, instance_id, context, depth)
#      16 serializer = SERIALIZERS[instance_type] if instance_type in SERIALIZERS else None
#      18 if serializer:
# ---> 19     return serializer(parent, instance, instance_id, context, depth)
#      21 if instance_type not in NO_SERIALIZER_FOR_INSTANCE:
#      22     # Only print the warning once for each type of serializer
#      23     logger.warning(f"!!!No serializer for {instance_type} with id {instance_id}")
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\modules\vtk\serializers\actors.py:31, in generic_actor_serializer(parent, actor, actor_id, context, depth)
#      29 if mapper:
#      30     mapper_id = reference_id(mapper)
# ---> 31     mapper_instance = serialize(actor, mapper, mapper_id, context, depth + 1)
#      32     if mapper_instance:
#      33         dependencies.append(mapper_instance)
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\modules\vtk\serializers\serialize.py:19, in serialize(parent, instance, instance_id, context, depth)
#      16 serializer = SERIALIZERS[instance_type] if instance_type in SERIALIZERS else None
#      18 if serializer:
# ---> 19     return serializer(parent, instance, instance_id, context, depth)
#      21 if instance_type not in NO_SERIALIZER_FOR_INSTANCE:
#      22     # Only print the warning once for each type of serializer
#      23     logger.warning(f"!!!No serializer for {instance_type} with id {instance_id}")
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\modules\vtk\serializers\mappers.py:37, in generic_mapper_serializer(parent, mapper, mapper_id, context, depth)
#      34     data_object = alg.GetOutput()
#      36 data_object_id = "%s-dataset" % mapper_id
# ---> 37 data_object_instance = serialize(
#      38     mapper, data_object, data_object_id, context, depth + 1
#      39 )
#      41 if data_object_instance:
#      42     dependencies.append(data_object_instance)
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\modules\vtk\serializers\serialize.py:19, in serialize(parent, instance, instance_id, context, depth)
#      16 serializer = SERIALIZERS[instance_type] if instance_type in SERIALIZERS else None
#      18 if serializer:
# ---> 19     return serializer(parent, instance, instance_id, context, depth)
#      21 if instance_type not in NO_SERIALIZER_FOR_INSTANCE:
#      22     # Only print the warning once for each type of serializer
#      23     logger.warning(f"!!!No serializer for {instance_type} with id {instance_id}")
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\modules\vtk\serializers\data.py:39, in polydata_serializer(parent, dataset, dataset_id, context, depth, requested_fields)
#      37 # Polys
#      38 if dataset.GetPolys() and dataset.GetPolys().GetData().GetNumberOfTuples() > 0:
# ---> 39     _polys = get_array_description(dataset.GetPolys().GetData(), context)
#      40     properties["polys"] = _polys
#      41     properties["polys"]["vtkClass"] = "vtkCellArray"
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\modules\vtk\serializers\helpers.py:76, in get_array_description(array, context)
#      73 if not array:
#      74     return None
# ---> 76 p_md5 = digest(array)
#      77 context.cache_data_array(
#      78     p_md5, {"array": array, "mTime": array.GetMTime(), "ts": time.time()}
#      79 )
#      81 root = {}
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\modules\vtk\serializers\helpers.py:51, in digest(array)
#      48 if record and record["mtime"] == array.GetMTime():
#      49     return record["sha"]
# ---> 51 record = {"sha": hash_data_array(array), "mtime": array.GetMTime()}
#      53 data_array_sha_mapping[obj_id] = record
#      54 return record["sha"]
#
# File c:\Users\cemre\Repos\Ifc-Voxelization\.venv\lib\site-packages\trame_vtk\modules\vtk\serializers\utils.py:51, in hash_data_array(data_array)
#      50 def hash_data_array(data_array):
# ---> 51     hashed_bit = hashlib.md5(memoryview(data_array)).hexdigest()
#      52     type_code = array_types_mapping[data_array.GetDataType()]
#      53     return "%s_%d%s" % (hashed_bit, data_array.GetSize(), type_code)
#
# KeyboardInterrupt:
