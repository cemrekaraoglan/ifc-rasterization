# %% [markdown]
# # IFC Rasterization for Efficient Spatial Analysis

# %% [markdown]
# ## Intro

# %% [markdown]
# ### Import libraries and the IFC model:

# %%
import pyvista as pv
import numpy as np
from typing import Any, Tuple
import ifcopenshell
import logging
from importlib import reload 
import multiprocessing
import ifcopenshell
import ifcopenshell.geom
import time
import vtk
ifc_file = ifcopenshell.open(r"IFC Files\Project1.ifc")
#ifc_file = ifcopenshell.open(r"IFC Files\Duplex.ifc")

# %% [markdown]
# ### Logging setup:

# %% [markdown]
# ## Functions

# %%
def to_vtk_faces(faces : Tuple[tuple]) -> np.ndarray:
    faces=np.array(faces, dtype=np.int16)
    num_insertions = (len(faces) - 1) // 3
    # Generate an array of indices for insertions
    indices = np.arange(3, 3 * (num_insertions + 1), 3)
    indices = np.insert(indices, 0, 0)
    faces = np.insert(faces, indices, 3)
    return faces

def vtk_block_by_building_element(ifc_file):
    building_elements = ifc_file.by_type("IfcBuildingElement")
    settings = ifcopenshell.geom.settings()
    settings.set(settings.USE_WORLD_COORDS, True)
    settings.set(settings.APPLY_DEFAULT_MATERIALS, True)
    iterator = ifcopenshell.geom.iterator(settings, ifc_file, multiprocessing.cpu_count())
    multiblock = pv.MultiBlock()
    element_information = {} # Dictionary to hold element information
    exclude_list = ["IfcSpace", "IfcOpeningElement"]

    if iterator.initialize():
        while True:
            shape = iterator.get()
            if shape.type not in exclude_list:
                element = ifc_file.by_guid(shape.guid)
                           
                faces = shape.geometry.faces
                verts = shape.geometry.verts
                poly_data = pv.PolyData(list(verts), to_vtk_faces(faces))
                multiblock.append(poly_data)
                  
                if element in building_elements:
                #print(element.all_attributes()) --> why doesn't it work?
                        
                    element_information[shape.guid] = {
                    "Geo": poly_data, 
                    "Type": shape.type,
                    "Name": element.Name,
                    "Description": element.Description
                    }
                            
                       
            if not iterator.next():
                break
                
    return multiblock, element_information

def create_uniform_grid(bounds, voxel_size):
    """Create a uniform grid within the given bounds."""
    x = np.arange(bounds[0], bounds[1] + voxel_size, voxel_size)
    y = np.arange(bounds[2], bounds[3] + voxel_size, voxel_size)
    z = np.arange(bounds[4], bounds[5] + voxel_size, voxel_size)
    return pv.StructuredGrid(*np.meshgrid(x, y, z))

def calculate_offset_points(cell_center, voxel_size):
    offset = voxel_size / 4
    offset_points = [
        cell_center + np.array([offset, 0, 0]),  # Point offset in the +x direction
        cell_center - np.array([offset, 0, 0]),  # Point offset in the -x direction
        cell_center + np.array([0, offset, 0]),  # Point offset in the +y direction
        cell_center - np.array([0, offset, 0]),  # Point offset in the -y direction
        cell_center + np.array([0, 0, offset]),  # Point offset in the +z direction
        cell_center - np.array([0, 0, offset])   # Point offset in the -z direction
    ]
    return offset_points

# %%
def voxelize_space(meshes, voxel_size, mesh_info):
    """Voxelize space and check intersections with given mesh."""
    grid = create_uniform_grid(meshes.bounds, voxel_size)

    num_points = grid.cell_centers().n_points
    
    mask = np.zeros(num_points, dtype=bool)

    cell_to_guid = {}

    print(f'Total number of voxels: {num_points}')

    select_enclosed = vtk.vtkSelectEnclosedPoints()
    select_enclosed_corners = vtk.vtkSelectEnclosedPoints()
    select_enclosed.SetInputData(grid.cell_centers())
    
    for guid, mesh_data in mesh_info.items():
        mesh = mesh_data['Geo']
        select_enclosed.SetSurfaceData(mesh)
        select_enclosed_corners.SetSurfaceData(mesh)
        select_enclosed.Update()
        
    for i in range(num_points):
        print(i)

        if not mask[i] and select_enclosed.IsInside(i):
            mask[i] = True
            cell_to_guid[i] = guid

        else:
            cell_center = grid.cell_centers().points[i]
            offset_points = calculate_offset_points(cell_center, voxel_size)
            print(offset_points)

            for ind, offset_point in enumerate(offset_points):
                offset_point_polydata = pv.PolyData(np.array([offset_point]))
                select_enclosed_corners.SetInputData(offset_point_polydata)
                select_enclosed_corners.Update()
                print(select_enclosed_corners)
                if not mask[i] and select_enclosed_corners.IsInside(ind):
                    mask[i] = True
                    break
                            
    return grid, mask, cell_to_guid

# %% [markdown]
# ## Voxelization

# %%
all_meshes, info = vtk_block_by_building_element(ifc_file)

p = pv.Plotter()

start_time = time.time()

voxel_size = 0.5

# Voxelize the entire space of the combined mesh
grid, mask2, cell_info = voxelize_space(all_meshes, voxel_size, info)

# Prepare to store cell-IFC-object mappings
'''cell_data = {}

for cell_id, guid in cell_info.items():
    cell_data[cell_id] = info[guid]
'''
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to voxelize: {elapsed_time:.4f} seconds")

# Visualization
p.add_mesh(grid, opacity=0.3, show_edges=True)
 
p.add_mesh(grid.extract_cells(np.where(mask2)[0]), color="red", opacity=0.5)

p.show()
# Out:
# Total number of voxels: 800
# 0
# [pyvista_ndarray([-1.93190329, -2.4290849 , -0.23      ]), pyvista_ndarray([-2.18190329, -2.4290849 , -0.23      ]), pyvista_ndarray([-2.05690329, -2.3040849 , -0.23      ]), pyvista_ndarray([-2.05690329, -2.5540849 , -0.23      ]), pyvista_ndarray([-2.05690329, -2.4290849 , -0.105     ]), pyvista_ndarray([-2.05690329, -2.4290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96133203
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96133513
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96133739
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96133964
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96134189
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 1
# [pyvista_ndarray([-1.93190329, -1.9290849 , -0.23      ]), pyvista_ndarray([-2.18190329, -1.9290849 , -0.23      ]), pyvista_ndarray([-2.05690329, -1.8040849 , -0.23      ]), pyvista_ndarray([-2.05690329, -2.0540849 , -0.23      ]), pyvista_ndarray([-2.05690329, -1.9290849 , -0.105     ]), pyvista_ndarray([-2.05690329, -1.9290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96134941
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96135166
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 2
# [pyvista_ndarray([-1.93190329, -1.4290849 , -0.23      ]), pyvista_ndarray([-2.18190329, -1.4290849 , -0.23      ]), pyvista_ndarray([-2.05690329, -1.3040849 , -0.23      ]), pyvista_ndarray([-2.05690329, -1.5540849 , -0.23      ]), pyvista_ndarray([-2.05690329, -1.4290849 , -0.105     ]), pyvista_ndarray([-2.05690329, -1.4290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96135918
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96136143
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 3
# [pyvista_ndarray([-1.93190329, -0.9290849 , -0.23      ]), pyvista_ndarray([-2.18190329, -0.9290849 , -0.23      ]), pyvista_ndarray([-2.05690329, -0.8040849 , -0.23      ]), pyvista_ndarray([-2.05690329, -1.0540849 , -0.23      ]), pyvista_ndarray([-2.05690329, -0.9290849 , -0.105     ]), pyvista_ndarray([-2.05690329, -0.9290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96136895
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96137120
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96137345
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 4
# [pyvista_ndarray([-1.93190329, -0.4290849 , -0.23      ]), pyvista_ndarray([-2.18190329, -0.4290849 , -0.23      ]), pyvista_ndarray([-2.05690329, -0.3040849 , -0.23      ]), pyvista_ndarray([-2.05690329, -0.5540849 , -0.23      ]), pyvista_ndarray([-2.05690329, -0.4290849 , -0.105     ]), pyvista_ndarray([-2.05690329, -0.4290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96138097
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96138322
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96138547
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 5
# [pyvista_ndarray([-1.93190329,  0.0709151 , -0.23      ]), pyvista_ndarray([-2.18190329,  0.0709151 , -0.23      ]), pyvista_ndarray([-2.05690329,  0.1959151 , -0.23      ]), pyvista_ndarray([-2.05690329, -0.0540849 , -0.23      ]), pyvista_ndarray([-2.05690329,  0.0709151 , -0.105     ]), pyvista_ndarray([-2.05690329,  0.0709151 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96139299
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96139524
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96139749
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96139974
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 6
# [pyvista_ndarray([-1.93190329,  0.5709151 , -0.23      ]), pyvista_ndarray([-2.18190329,  0.5709151 , -0.23      ]), pyvista_ndarray([-2.05690329,  0.6959151 , -0.23      ]), pyvista_ndarray([-2.05690329,  0.4459151 , -0.23      ]), pyvista_ndarray([-2.05690329,  0.5709151 , -0.105     ]), pyvista_ndarray([-2.05690329,  0.5709151 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96140726
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96140951
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 7
# [pyvista_ndarray([-1.93190329,  1.0709151 , -0.23      ]), pyvista_ndarray([-2.18190329,  1.0709151 , -0.23      ]), pyvista_ndarray([-2.05690329,  1.1959151 , -0.23      ]), pyvista_ndarray([-2.05690329,  0.9459151 , -0.23      ]), pyvista_ndarray([-2.05690329,  1.0709151 , -0.105     ]), pyvista_ndarray([-2.05690329,  1.0709151 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96141703
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96141928
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96142153
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96142378
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96142603
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 8
# [pyvista_ndarray([-1.93190329,  1.5709151 , -0.23      ]), pyvista_ndarray([-2.18190329,  1.5709151 , -0.23      ]), pyvista_ndarray([-2.05690329,  1.6959151 , -0.23      ]), pyvista_ndarray([-2.05690329,  1.4459151 , -0.23      ]), pyvista_ndarray([-2.05690329,  1.5709151 , -0.105     ]), pyvista_ndarray([-2.05690329,  1.5709151 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96143355
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96143580
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 9
# [pyvista_ndarray([-1.93190329,  2.0709151 , -0.23      ]), pyvista_ndarray([-2.18190329,  2.0709151 , -0.23      ]), pyvista_ndarray([-2.05690329,  2.1959151 , -0.23      ]), pyvista_ndarray([-2.05690329,  1.9459151 , -0.23      ]), pyvista_ndarray([-2.05690329,  2.0709151 , -0.105     ]), pyvista_ndarray([-2.05690329,  2.0709151 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96144332
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96144557
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 10
# [pyvista_ndarray([-1.43190329, -2.4290849 , -0.23      ]), pyvista_ndarray([-1.68190329, -2.4290849 , -0.23      ]), pyvista_ndarray([-1.55690329, -2.3040849 , -0.23      ]), pyvista_ndarray([-1.55690329, -2.5540849 , -0.23      ]), pyvista_ndarray([-1.55690329, -2.4290849 , -0.105     ]), pyvista_ndarray([-1.55690329, -2.4290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96145309
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96145534
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96145759
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96145984
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 11
# [pyvista_ndarray([-1.43190329, -1.9290849 , -0.23      ]), pyvista_ndarray([-1.68190329, -1.9290849 , -0.23      ]), pyvista_ndarray([-1.55690329, -1.8040849 , -0.23      ]), pyvista_ndarray([-1.55690329, -2.0540849 , -0.23      ]), pyvista_ndarray([-1.55690329, -1.9290849 , -0.105     ]), pyvista_ndarray([-1.55690329, -1.9290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96146736
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96146961
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96147186
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 12
# [pyvista_ndarray([-1.43190329, -1.4290849 , -0.23      ]), pyvista_ndarray([-1.68190329, -1.4290849 , -0.23      ]), pyvista_ndarray([-1.55690329, -1.3040849 , -0.23      ]), pyvista_ndarray([-1.55690329, -1.5540849 , -0.23      ]), pyvista_ndarray([-1.55690329, -1.4290849 , -0.105     ]), pyvista_ndarray([-1.55690329, -1.4290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96147938
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96148163
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 13
# [pyvista_ndarray([-1.43190329, -0.9290849 , -0.23      ]), pyvista_ndarray([-1.68190329, -0.9290849 , -0.23      ]), pyvista_ndarray([-1.55690329, -0.8040849 , -0.23      ]), pyvista_ndarray([-1.55690329, -1.0540849 , -0.23      ]), pyvista_ndarray([-1.55690329, -0.9290849 , -0.105     ]), pyvista_ndarray([-1.55690329, -0.9290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96148915
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96149140
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 14
# [pyvista_ndarray([-1.43190329, -0.4290849 , -0.23      ]), pyvista_ndarray([-1.68190329, -0.4290849 , -0.23      ]), pyvista_ndarray([-1.55690329, -0.3040849 , -0.23      ]), pyvista_ndarray([-1.55690329, -0.5540849 , -0.23      ]), pyvista_ndarray([-1.55690329, -0.4290849 , -0.105     ]), pyvista_ndarray([-1.55690329, -0.4290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96149892
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96150117
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 15
# [pyvista_ndarray([-1.43190329,  0.0709151 , -0.23      ]), pyvista_ndarray([-1.68190329,  0.0709151 , -0.23      ]), pyvista_ndarray([-1.55690329,  0.1959151 , -0.23      ]), pyvista_ndarray([-1.55690329, -0.0540849 , -0.23      ]), pyvista_ndarray([-1.55690329,  0.0709151 , -0.105     ]), pyvista_ndarray([-1.55690329,  0.0709151 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96150869
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96151094
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96151319
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 16
# [pyvista_ndarray([-1.43190329,  0.5709151 , -0.23      ]), pyvista_ndarray([-1.68190329,  0.5709151 , -0.23      ]), pyvista_ndarray([-1.55690329,  0.6959151 , -0.23      ]), pyvista_ndarray([-1.55690329,  0.4459151 , -0.23      ]), pyvista_ndarray([-1.55690329,  0.5709151 , -0.105     ]), pyvista_ndarray([-1.55690329,  0.5709151 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96152071
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96152296
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96152521
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 17
# [pyvista_ndarray([-1.43190329,  1.0709151 , -0.23      ]), pyvista_ndarray([-1.68190329,  1.0709151 , -0.23      ]), pyvista_ndarray([-1.55690329,  1.1959151 , -0.23      ]), pyvista_ndarray([-1.55690329,  0.9459151 , -0.23      ]), pyvista_ndarray([-1.55690329,  1.0709151 , -0.105     ]), pyvista_ndarray([-1.55690329,  1.0709151 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96153273
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96153498
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96153723
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 18
# [pyvista_ndarray([-1.43190329,  1.5709151 , -0.23      ]), pyvista_ndarray([-1.68190329,  1.5709151 , -0.23      ]), pyvista_ndarray([-1.55690329,  1.6959151 , -0.23      ]), pyvista_ndarray([-1.55690329,  1.4459151 , -0.23      ]), pyvista_ndarray([-1.55690329,  1.5709151 , -0.105     ]), pyvista_ndarray([-1.55690329,  1.5709151 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96154475
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96154700
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 19
# [pyvista_ndarray([-1.43190329,  2.0709151 , -0.23      ]), pyvista_ndarray([-1.68190329,  2.0709151 , -0.23      ]), pyvista_ndarray([-1.55690329,  2.1959151 , -0.23      ]), pyvista_ndarray([-1.55690329,  1.9459151 , -0.23      ]), pyvista_ndarray([-1.55690329,  2.0709151 , -0.105     ]), pyvista_ndarray([-1.55690329,  2.0709151 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96155452
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96155677
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96155902
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 20
# [pyvista_ndarray([-0.93190329, -2.4290849 , -0.23      ]), pyvista_ndarray([-1.18190329, -2.4290849 , -0.23      ]), pyvista_ndarray([-1.05690329, -2.3040849 , -0.23      ]), pyvista_ndarray([-1.05690329, -2.5540849 , -0.23      ]), pyvista_ndarray([-1.05690329, -2.4290849 , -0.105     ]), pyvista_ndarray([-1.05690329, -2.4290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96156654
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96156879
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96157104
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 21
# [pyvista_ndarray([-0.93190329, -1.9290849 , -0.23      ]), pyvista_ndarray([-1.18190329, -1.9290849 , -0.23      ]), pyvista_ndarray([-1.05690329, -1.8040849 , -0.23      ]), pyvista_ndarray([-1.05690329, -2.0540849 , -0.23      ]), pyvista_ndarray([-1.05690329, -1.9290849 , -0.105     ]), pyvista_ndarray([-1.05690329, -1.9290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96157856
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96158081
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96158306
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96158531
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96158756
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 22
# [pyvista_ndarray([-0.93190329, -1.4290849 , -0.23      ]), pyvista_ndarray([-1.18190329, -1.4290849 , -0.23      ]), pyvista_ndarray([-1.05690329, -1.3040849 , -0.23      ]), pyvista_ndarray([-1.05690329, -1.5540849 , -0.23      ]), pyvista_ndarray([-1.05690329, -1.4290849 , -0.105     ]), pyvista_ndarray([-1.05690329, -1.4290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96159508
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96159733
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96159958
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96160183
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 23
# [pyvista_ndarray([-0.93190329, -0.9290849 , -0.23      ]), pyvista_ndarray([-1.18190329, -0.9290849 , -0.23      ]), pyvista_ndarray([-1.05690329, -0.8040849 , -0.23      ]), pyvista_ndarray([-1.05690329, -1.0540849 , -0.23      ]), pyvista_ndarray([-1.05690329, -0.9290849 , -0.105     ]), pyvista_ndarray([-1.05690329, -0.9290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96160935
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96161160
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 24
# [pyvista_ndarray([-0.93190329, -0.4290849 , -0.23      ]), pyvista_ndarray([-1.18190329, -0.4290849 , -0.23      ]), pyvista_ndarray([-1.05690329, -0.3040849 , -0.23      ]), pyvista_ndarray([-1.05690329, -0.5540849 , -0.23      ]), pyvista_ndarray([-1.05690329, -0.4290849 , -0.105     ]), pyvista_ndarray([-1.05690329, -0.4290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96161912
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96162137
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 25
# [pyvista_ndarray([-0.93190329,  0.0709151 , -0.23      ]), pyvista_ndarray([-1.18190329,  0.0709151 , -0.23      ]), pyvista_ndarray([-1.05690329,  0.1959151 , -0.23      ]), pyvista_ndarray([-1.05690329, -0.0540849 , -0.23      ]), pyvista_ndarray([-1.05690329,  0.0709151 , -0.105     ]), pyvista_ndarray([-1.05690329,  0.0709151 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96162889
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96163114
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96163339
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96163564
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 26
# [pyvista_ndarray([-0.93190329,  0.5709151 , -0.23      ]), pyvista_ndarray([-1.18190329,  0.5709151 , -0.23      ]), pyvista_ndarray([-1.05690329,  0.6959151 , -0.23      ]), pyvista_ndarray([-1.05690329,  0.4459151 , -0.23      ]), pyvista_ndarray([-1.05690329,  0.5709151 , -0.105     ]), pyvista_ndarray([-1.05690329,  0.5709151 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96164316
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96164541
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96164766
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96164991
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 27
# [pyvista_ndarray([-0.93190329,  1.0709151 , -0.23      ]), pyvista_ndarray([-1.18190329,  1.0709151 , -0.23      ]), pyvista_ndarray([-1.05690329,  1.1959151 , -0.23      ]), pyvista_ndarray([-1.05690329,  0.9459151 , -0.23      ]), pyvista_ndarray([-1.05690329,  1.0709151 , -0.105     ]), pyvista_ndarray([-1.05690329,  1.0709151 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96165743
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96165968
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96166193
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96166418
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96166643
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 28
# [pyvista_ndarray([-0.93190329,  1.5709151 , -0.23      ]), pyvista_ndarray([-1.18190329,  1.5709151 , -0.23      ]), pyvista_ndarray([-1.05690329,  1.6959151 , -0.23      ]), pyvista_ndarray([-1.05690329,  1.4459151 , -0.23      ]), pyvista_ndarray([-1.05690329,  1.5709151 , -0.105     ]), pyvista_ndarray([-1.05690329,  1.5709151 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96167395
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96167620
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96167845
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96168070
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 29
# [pyvista_ndarray([-0.93190329,  2.0709151 , -0.23      ]), pyvista_ndarray([-1.18190329,  2.0709151 , -0.23      ]), pyvista_ndarray([-1.05690329,  2.1959151 , -0.23      ]), pyvista_ndarray([-1.05690329,  1.9459151 , -0.23      ]), pyvista_ndarray([-1.05690329,  2.0709151 , -0.105     ]), pyvista_ndarray([-1.05690329,  2.0709151 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96168822
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96169047
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96169272
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96169497
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 30
# [pyvista_ndarray([-0.43190329, -2.4290849 , -0.23      ]), pyvista_ndarray([-0.68190329, -2.4290849 , -0.23      ]), pyvista_ndarray([-0.55690329, -2.3040849 , -0.23      ]), pyvista_ndarray([-0.55690329, -2.5540849 , -0.23      ]), pyvista_ndarray([-0.55690329, -2.4290849 , -0.105     ]), pyvista_ndarray([-0.55690329, -2.4290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96170249
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96170474
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96170699
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96170924
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96171149
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 31
# [pyvista_ndarray([-0.43190329, -1.9290849 , -0.23      ]), pyvista_ndarray([-0.68190329, -1.9290849 , -0.23      ]), pyvista_ndarray([-0.55690329, -1.8040849 , -0.23      ]), pyvista_ndarray([-0.55690329, -2.0540849 , -0.23      ]), pyvista_ndarray([-0.55690329, -1.9290849 , -0.105     ]), pyvista_ndarray([-0.55690329, -1.9290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96171901
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96172126
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 32
# [pyvista_ndarray([-0.43190329, -1.4290849 , -0.23      ]), pyvista_ndarray([-0.68190329, -1.4290849 , -0.23      ]), pyvista_ndarray([-0.55690329, -1.3040849 , -0.23      ]), pyvista_ndarray([-0.55690329, -1.5540849 , -0.23      ]), pyvista_ndarray([-0.55690329, -1.4290849 , -0.105     ]), pyvista_ndarray([-0.55690329, -1.4290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96172878
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96173103
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96173328
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96173553
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 33
# [pyvista_ndarray([-0.43190329, -0.9290849 , -0.23      ]), pyvista_ndarray([-0.68190329, -0.9290849 , -0.23      ]), pyvista_ndarray([-0.55690329, -0.8040849 , -0.23      ]), pyvista_ndarray([-0.55690329, -1.0540849 , -0.23      ]), pyvista_ndarray([-0.55690329, -0.9290849 , -0.105     ]), pyvista_ndarray([-0.55690329, -0.9290849 , -0.355     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96174305
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 96174530
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 34
# ...
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97124754
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 790
# [pyvista_ndarray([ 2.56809671, -2.4290849 ,  3.27      ]), pyvista_ndarray([ 2.31809671, -2.4290849 ,  3.27      ]), pyvista_ndarray([ 2.44309671, -2.3040849 ,  3.27      ]), pyvista_ndarray([ 2.44309671, -2.5540849 ,  3.27      ]), pyvista_ndarray([ 2.44309671, -2.4290849 ,  3.395     ]), pyvista_ndarray([ 2.44309671, -2.4290849 ,  3.145     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97125506
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97125731
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97125956
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97126181
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97126406
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 791
# [pyvista_ndarray([ 2.56809671, -1.9290849 ,  3.27      ]), pyvista_ndarray([ 2.31809671, -1.9290849 ,  3.27      ]), pyvista_ndarray([ 2.44309671, -1.8040849 ,  3.27      ]), pyvista_ndarray([ 2.44309671, -2.0540849 ,  3.27      ]), pyvista_ndarray([ 2.44309671, -1.9290849 ,  3.395     ]), pyvista_ndarray([ 2.44309671, -1.9290849 ,  3.145     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97127158
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97127383
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 792
# [pyvista_ndarray([ 2.56809671, -1.4290849 ,  3.27      ]), pyvista_ndarray([ 2.31809671, -1.4290849 ,  3.27      ]), pyvista_ndarray([ 2.44309671, -1.3040849 ,  3.27      ]), pyvista_ndarray([ 2.44309671, -1.5540849 ,  3.27      ]), pyvista_ndarray([ 2.44309671, -1.4290849 ,  3.395     ]), pyvista_ndarray([ 2.44309671, -1.4290849 ,  3.145     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97128135
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97128360
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97128585
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97128810
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97129035
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 793
# [pyvista_ndarray([ 2.56809671, -0.9290849 ,  3.27      ]), pyvista_ndarray([ 2.31809671, -0.9290849 ,  3.27      ]), pyvista_ndarray([ 2.44309671, -0.8040849 ,  3.27      ]), pyvista_ndarray([ 2.44309671, -1.0540849 ,  3.27      ]), pyvista_ndarray([ 2.44309671, -0.9290849 ,  3.395     ]), pyvista_ndarray([ 2.44309671, -0.9290849 ,  3.145     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97129787
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97130012
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 794
# [pyvista_ndarray([ 2.56809671, -0.4290849 ,  3.27      ]), pyvista_ndarray([ 2.31809671, -0.4290849 ,  3.27      ]), pyvista_ndarray([ 2.44309671, -0.3040849 ,  3.27      ]), pyvista_ndarray([ 2.44309671, -0.5540849 ,  3.27      ]), pyvista_ndarray([ 2.44309671, -0.4290849 ,  3.395     ]), pyvista_ndarray([ 2.44309671, -0.4290849 ,  3.145     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97130764
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97130989
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97131214
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97131439
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97131664
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 795
# [pyvista_ndarray([2.56809671, 0.0709151 , 3.27      ]), pyvista_ndarray([2.31809671, 0.0709151 , 3.27      ]), pyvista_ndarray([2.44309671, 0.1959151 , 3.27      ]), pyvista_ndarray([ 2.44309671, -0.0540849 ,  3.27      ]), pyvista_ndarray([2.44309671, 0.0709151 , 3.395     ]), pyvista_ndarray([2.44309671, 0.0709151 , 3.145     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97132416
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97132641
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97132866
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97133091
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 796
# [pyvista_ndarray([2.56809671, 0.5709151 , 3.27      ]), pyvista_ndarray([2.31809671, 0.5709151 , 3.27      ]), pyvista_ndarray([2.44309671, 0.6959151 , 3.27      ]), pyvista_ndarray([2.44309671, 0.4459151 , 3.27      ]), pyvista_ndarray([2.44309671, 0.5709151 , 3.395     ]), pyvista_ndarray([2.44309671, 0.5709151 , 3.145     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97133843
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97134068
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 797
# [pyvista_ndarray([2.56809671, 1.0709151 , 3.27      ]), pyvista_ndarray([2.31809671, 1.0709151 , 3.27      ]), pyvista_ndarray([2.44309671, 1.1959151 , 3.27      ]), pyvista_ndarray([2.44309671, 0.9459151 , 3.27      ]), pyvista_ndarray([2.44309671, 1.0709151 , 3.395     ]), pyvista_ndarray([2.44309671, 1.0709151 , 3.145     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97134820
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97135045
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97135270
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97135495
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 798
# [pyvista_ndarray([2.56809671, 1.5709151 , 3.27      ]), pyvista_ndarray([2.31809671, 1.5709151 , 3.27      ]), pyvista_ndarray([2.44309671, 1.6959151 , 3.27      ]), pyvista_ndarray([2.44309671, 1.4459151 , 3.27      ]), pyvista_ndarray([2.44309671, 1.5709151 , 3.395     ]), pyvista_ndarray([2.44309671, 1.5709151 , 3.145     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97136247
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97136472
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# 799
# [pyvista_ndarray([2.56809671, 2.0709151 , 3.27      ]), pyvista_ndarray([2.31809671, 2.0709151 , 3.27      ]), pyvista_ndarray([2.44309671, 2.1959151 , 3.27      ]), pyvista_ndarray([2.44309671, 1.9459151 , 3.27      ]), pyvista_ndarray([2.44309671, 2.0709151 , 3.395     ]), pyvista_ndarray([2.44309671, 2.0709151 , 3.145     ])]
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97137224
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97137449
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97137674
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97137899
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# vtkSelectEnclosedPoints (000001E1EF252950)
#   Debug: Off
#   Modified Time: 97138124
#   Reference Count: 2
#   Registered Events: (none)
#   Executive: 000001E1F0F63540
#   ErrorCode: No error
#   Information: 000001E1F12A2330
#   AbortExecute: Off
#   Progress: 1
#   Progress Text: (None)
#   Check Surface: Off
#   Inside Out: Off
#   Tolerance: 0.0001
#
#
# Time taken to voxelize: 2.8906 seconds
# Widget(value="<iframe src='http://localhost:53577/index.html?ui=P_0x1e1f2040910_6&reconnect=auto' style='width…
